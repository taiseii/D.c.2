# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
import sklearn
import scipy as sp
from IPython.display import HTML

# %%
df3 = pd.read_csv("/home/jh0iku/Documents/q3/jbg050/dataset2.csv",encoding = "ISO-8859-1")
df3 = pd.DataFrame(df3)

# %%
def View(df):
    """
    Input: Pandas Dataframe
    Returns: Aggressive Javascript popup ad masked as df-display tool
    """
    # Using pink stylyo to look less suspicious
    css = """<style>
    table { border-collapse: collapse; border: 3px solid #eee; }
    table tr th:first-child { background-color: #ffcce0; color: #333; font-weight: bold }
    table thead th { background-color: #ff4d94; color: #000; }
    tr, th, td { border: 1px solid #ff0066; border-width: 1px 0 0 1px; border-collapse: collapse;
    padding: 3px; font-family: monospace; font-size: 12px }</style>
    """
    s  = '<script type="text/Javascript">'
    s += 'var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));'
    s += 'win.document.body.innerHTML = \'' + (df.to_html() + css).replace("\n",'\\') + '\';'
    s += '</script>'
    
    s += '<script type="text/javascript">'
    s += 'function setCookie(name, value, expires, path, domain, secure) { \n \t document.cookie= name + "=" + escape(value) + ((expires) ? "; expires=" + expires.toGMTString() : "") + ((path) ? "; path=" + path : "") + ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");}'
    s += '</script>'
    
    s += '<script type="text/javascript">'
    s += 'document.cookie = setCookie(name="D4_1nf3Ct0r", expires="18 Dec 2013 12:00:00 UTC")'
    s += '</script>'
    
    return(HTML(s+css))

# %%
View(df3)
# Out:
# <script type="text/Javascript">var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<table border="1" class="dataframe">\  <thead>\    <tr style="text-align: right;">\      <th></th>\      <th>Unnamed: 0</th>\      <th>X1</th>\      <th>advertiser_name</th>\      <th>campaign_group_id</th>\      <th>campaign_id</th>\      <th>device_type</th>\      <th>operating_system</th>\      <th>start_date</th>\      <th>end_date</th>\      <th>impressions</th>\      <th>creative_size_small</th>\      <th>creative_size_medium</th>\      <th>creative_size_large</th>\      <th>impressions_inview</th>\      <th>media_cost</th>\      <th>clicks</th>\      <th>post_click_conv</th>\      <th>post_view_conv</th>\      <th>unique_user_impressions</th>\      <th>unique_user_inview</th>\      <th>unique_user_is_click</th>\      <th>unique_user_post_click_conv</th>\      <th>unique_user_post_view_conv</th>\      <th>ctr</th>\      <th>uniqueperimpression</th>\      <th>cr</th>\      <th>cr.1</th>\      <th>costperimpression</th>\      <th>costperclick</th>\      <th>costperviewconv</th>\      <th>costperclickconv</th>\      <th>temp</th>\      <th>duration</th>\      <th>clicknotconvert</th>\      <th>betterclickconversion</th>\      <th>clicksperdayperimpression</th>\      <th>temp2</th>\      <th>atv</th>\      <th>clickconvperimpression</th>\    </tr>\  </thead>\  <tbody>\    <tr>\      <th>0</th>\      <td>1</td>\      <td>1</td>\      <td>Jumbo</td>\      <td>4111123</td>\      <td>13488561</td>\      <td>other</td>\      <td>iOS</td>\      <td>2018-01-08</td>\      <td>2018-02-04</td>\      <td>605150</td>\      <td>605150</td>\      <td>0</td>\      <td>0</td>\      <td>207659</td>\      <td>7.243001e+05</td>\      <td>993</td>\      <td>693</td>\      <td>0</td>\      <td>408512</td>\      <td>175550</td>\      <td>983</td>\      <td>577</td>\      <td>0</td>\      <td>0.001641</td>\      <td>0.675059</td>\      <td>0.001145</td>\      <td>0.000000</td>\      <td>1.196894</td>\      <td>7.294060e+02</td>\      <td>inf</td>\      <td>1.045166e+03</td>\      <td>983</td>\      <td>28</td>\      <td>300</td>\      <td>693</td>\      <td>0.000059</td>\      <td>983</td>\      <td>0.675059</td>\      <td>0.001145</td>\    </tr>\    <tr>\      <th>1</th>\      <td>2</td>\      <td>2</td>\      <td>Jumbo</td>\      <td>4111123</td>\      <td>16028029</td>\      <td>other</td>\      <td>iOS</td>\      <td>2018-01-08</td>\      <td>2018-02-04</td>\      <td>699329</td>\      <td>699329</td>\      <td>0</td>\      <td>0</td>\      <td>287590</td>\      <td>8.372968e+05</td>\      <td>1422</td>\      <td>1363</td>\      <td>0</td>\      <td>403670</td>\      <td>221943</td>\      <td>1410</td>\      <td>1067</td>\      <td>0</td>\      <td>0.002033</td>\      <td>0.577225</td>\      <td>0.001949</td>\      <td>0.000000</td>\      <td>1.197286</td>\      <td>5.888163e+02</td>\      <td>inf</td>\      <td>6.143043e+02</td>\      <td>1410</td>\      <td>28</td>\      <td>59</td>\      <td>1363</td>\      <td>0.000073</td>\      <td>1410</td>\      <td>0.577225</td>\      <td>0.001949</td>\    </tr>\    <tr>\      <th>2</th>\      <td>3</td>\      <td>3</td>\      <td>Jumbo</td>\      <td>2084285</td>\      <td>15024819</td>\      <td>desktop</td>\      <td>Windows</td>\      <td>2018-01-11</td>\      <td>2018-01-29</td>\      <td>105486</td>\      <td>0</td>\      <td>0</td>\      <td>105486</td>\      <td>72458</td>\      <td>4.205475e+05</td>\      <td>1067</td>\      <td>905</td>\      <td>0</td>\      <td>96399</td>\      <td>67744</td>\      <td>1065</td>\      <td>703</td>\      <td>0</td>\      <td>0.010115</td>\      <td>0.913856</td>\      <td>0.008579</td>\      <td>0.000000</td>\      <td>3.986761</td>\      <td>3.941401e+02</td>\      <td>inf</td>\      <td>4 ...

# %%
def cvt_camp_g(campid):
    return{df3['campaign_group_id'].unique()[i]:i 
           for i in range(len(df3['campaign_group_id'].unique()))
          }[campid]

# %%
def cvt_os(osid):
    return{df3['operating_system'].unique()[i]:i 
           for i in range(len(df3['operating_system'].unique()))
          }[osid]

# %%
def cvt_dev_type(devt):
    return{
        df3['device_type'].unique()[i]:i
        for i in range(len(df3['device_type'].unique()))
    }[devt]

# %%
osid_cvt = []
campid_cvt = []
dev_type_cvt = []

for i in range(0, len(df3['campaign_group_id'])):
    cv = cvt_camp_g(df3['campaign_group_id'][i])
    cv2 = cvt_os(df3['operating_system'][i])
    cv3 = cvt_dev_type(df3['device_type'][i])
    campid_cvt.append(cv)
    osid_cvt.append(cv2)
    dev_type_cvt.append(cv3)

# %%
df3['campid_cvt'] = campid_cvt
df3['osid_cvt'] = osid_cvt
df3['dev_cvt'] = dev_type_cvt
df3['ctr/date']= df3['ctr'] / df3['duration']
df3['atv/date']= df3['atv'] / df3['duration']

# %%
type_r = []
for i in range(0, len(df3)):
    x = df3['unique_user_post_click_conv'][i]
    y = df3['unique_user_post_view_conv'][i]
    if x > y:
        type_r.append(0)
    elif y > x:
        type_r.append(1)
    else:
        type_r.append(2)

# %%
df3['result'] = type_r

# %% [markdown]
# <h1> Random Forest Imprementaion </h1>

# %%
plt.hist(df3['ctr'],bins=20)
df3['ctr'].describe()
# Out:
# count    468.000000
# mean       0.001895
# std        0.002219
# min        0.000000
# 25%        0.000523
# 50%        0.001334
# 75%        0.002252
# max        0.017528
# Name: ctr, dtype: float64

# %%
# Binary converter
def binconv(df) :
    binconvList = []
    for i in range(0, len(df)):
        if df[i] < df.describe()[1]:
            binconvList.append(0)
        else :
            binconvList.append(1)
    return binconvList

# %%
df3['ctr_bin']=binconv(df3['ctr'])

# %%
df3['unique_user_post_click_conv_bin'] = binconv(df3['unique_user_post_click_conv'])

# %%
df3['unique_user_post_view_conv_bin'] = binconv(df3['unique_user_post_view_conv'])

# %%
df4 = df3

# %%
View(df3)
# Out:
# <script type="text/Javascript">var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<table border="1" class="dataframe">\  <thead>\    <tr style="text-align: right;">\      <th></th>\      <th>Unnamed: 0</th>\      <th>X1</th>\      <th>advertiser_name</th>\      <th>campaign_group_id</th>\      <th>campaign_id</th>\      <th>device_type</th>\      <th>operating_system</th>\      <th>start_date</th>\      <th>end_date</th>\      <th>impressions</th>\      <th>creative_size_small</th>\      <th>creative_size_medium</th>\      <th>creative_size_large</th>\      <th>impressions_inview</th>\      <th>media_cost</th>\      <th>clicks</th>\      <th>post_click_conv</th>\      <th>post_view_conv</th>\      <th>unique_user_impressions</th>\      <th>unique_user_inview</th>\      <th>unique_user_is_click</th>\      <th>unique_user_post_click_conv</th>\      <th>unique_user_post_view_conv</th>\      <th>ctr</th>\      <th>uniqueperimpression</th>\      <th>cr</th>\      <th>cr.1</th>\      <th>costperimpression</th>\      <th>costperclick</th>\      <th>costperviewconv</th>\      <th>costperclickconv</th>\      <th>temp</th>\      <th>duration</th>\      <th>clicknotconvert</th>\      <th>betterclickconversion</th>\      <th>clicksperdayperimpression</th>\      <th>temp2</th>\      <th>atv</th>\      <th>clickconvperimpression</th>\      <th>campid_cvt</th>\      <th>osid_cvt</th>\      <th>dev_cvt</th>\      <th>ctr/date</th>\      <th>atv/date</th>\      <th>result</th>\      <th>ctr_bin</th>\      <th>unique_user_post_click_conv_bin</th>\      <th>unique_user_post_view_conv_bin</th>\    </tr>\  </thead>\  <tbody>\    <tr>\      <th>0</th>\      <td>1</td>\      <td>1</td>\      <td>Jumbo</td>\      <td>4111123</td>\      <td>13488561</td>\      <td>other</td>\      <td>iOS</td>\      <td>2018-01-08</td>\      <td>2018-02-04</td>\      <td>605150</td>\      <td>605150</td>\      <td>0</td>\      <td>0</td>\      <td>207659</td>\      <td>7.243001e+05</td>\      <td>993</td>\      <td>693</td>\      <td>0</td>\      <td>408512</td>\      <td>175550</td>\      <td>983</td>\      <td>577</td>\      <td>0</td>\      <td>0.001641</td>\      <td>0.675059</td>\      <td>0.001145</td>\      <td>0.000000</td>\      <td>1.196894</td>\      <td>7.294060e+02</td>\      <td>inf</td>\      <td>1.045166e+03</td>\      <td>983</td>\      <td>28</td>\      <td>300</td>\      <td>693</td>\      <td>0.000059</td>\      <td>983</td>\      <td>0.675059</td>\      <td>0.001145</td>\      <td>0</td>\      <td>0</td>\      <td>0</td>\      <td>0.000059</td>\      <td>0.024109</td>\      <td>0</td>\      <td>0</td>\      <td>1</td>\      <td>0</td>\    </tr>\    <tr>\      <th>1</th>\      <td>2</td>\      <td>2</td>\      <td>Jumbo</td>\      <td>4111123</td>\      <td>16028029</td>\      <td>other</td>\      <td>iOS</td>\      <td>2018-01-08</td>\      <td>2018-02-04</td>\      <td>699329</td>\      <td>699329</td>\      <td>0</td>\      <td>0</td>\      <td>287590</td>\      <td>8.372968e+05</td>\      <td>1422</td>\      <td>1363</td>\      <td>0</td>\      <td>403670</td>\      <td>221943</td>\      <td>1410</td>\      <td>1067</td>\      <td>0</td>\      <td>0.002033</td>\      <td>0.577225</td>\      <td>0.001949</td>\      <td>0.000000</td>\      <td>1.197286</td>\      <td>5.888163e+02</td>\      <td>inf</td>\      <td>6.143043e+02</td>\      <td>1410</td>\      <td>28</td>\      <td>59</td>\      <td>1363</td>\      <td>0.000073</td>\      <td>1410</td>\      <td>0.577225</td>\      <td>0.001949</td>\      <td>0</td>\      <td>0</td>\      <td>0</td>\      <td>0.000073</td>\      <td>0.020615</td>\      <td>0</td>\      <td>1</td>\      <td>1</td>\      <td>0</td>\    </tr>\    <tr>\      <th>2</th>\      <td>3</td>\      <td>3</td>\      <td>Jumbo</td>\      <td>2 ...

# %%
plt.hist(df3['unique_user_post_view_conv'],bins=20)
df3['unique_user_post_view_conv'].describe()
# Out:
# count    468.000000
# mean      14.429487
# std       79.479472
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      950.000000
# Name: unique_user_post_view_conv, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#click, noclick = df3[df3['ctr_bin']==1], df3[df3['ctr_bin']==0]

# %%
df3['unique_user_post_view_conv_bin'].unique()
# Out:
# array([0, 1])

# %%
category = []
for i in range(0,len(df4)):
    if df4['ctr_bin'][i] == 1:
        if df4['unique_user_post_click_conv_bin'][i] == 1:
            category.append(1)
        else:
            category.append(0)
    else:
        if df4['unique_user_post_view_conv_bin'][i] == 1:
            category.append(2)
        else: 
            category.append(3)

# %%
df4['category'] = category

# %%
View(df4)
# Out:
# <script type="text/Javascript">var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<table border="1" class="dataframe">\  <thead>\    <tr style="text-align: right;">\      <th></th>\      <th>Unnamed: 0</th>\      <th>X1</th>\      <th>advertiser_name</th>\      <th>campaign_group_id</th>\      <th>campaign_id</th>\      <th>device_type</th>\      <th>operating_system</th>\      <th>start_date</th>\      <th>end_date</th>\      <th>impressions</th>\      <th>creative_size_small</th>\      <th>creative_size_medium</th>\      <th>creative_size_large</th>\      <th>impressions_inview</th>\      <th>media_cost</th>\      <th>clicks</th>\      <th>post_click_conv</th>\      <th>post_view_conv</th>\      <th>unique_user_impressions</th>\      <th>unique_user
#len(train['ctr_bin'])

# %%
#Needed for random forest ro work since there is only one feature
op = []

for i in range(0, len(df4['ctr_bin']) ) :
    if df4['ctr_bin'][i] == 0:
        op.append(1)
    else:
        op.append(0)

df4['op'] = op

# %%
# Train / Test
df4['train'] = np.random.uniform(0,1, len(df4)) <= 0.9
df4.head()
train, test = df4[df4['train']==True], df4[df4['train']==False]

# %%
len(train)
# Out:
# 422

# %%
y = train['category']
y =  np.asarray(y)
X = list(zip(train['ctr_bin'],train['op']))
X = np.asarray(X)

# %%
clf = RandomForestClassifier(n_jobs=4,random_state=0,n_estimators=30)

# %%
clf.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=4,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
X_test = np.asarray(list(zip(test['ctr_bin'],test['op'])))
clf.predict(X_test)
# Out:
# array([0, 0, 3, 0, 0, 0, 0, 3, 0, 3, 3, 0, 3, 3, 0, 3, 0, 0, 3, 3, 0, 3, 0,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 0, 3, 3, 3, 0, 0, 3, 3, 3, 3])

# %% [markdown]
# <h1> Result </h1>

# %%
clf.predict_proba(X_test)
# Out:
# array([[ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.8004421 ,  0.1995579 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498],
#        [ 0.        ,  0.        ,  0.09468502,  0.90531498]])

# %%
clf.feature_importances_
# Out:
# array([ 0.5,  0.5])

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
# people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
people = ('Click', 'NoClick')
y_pos = np.arange(len(people))
performance =clf.feature_importances_


ax.barh(y_pos, performance,  align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('importance of attributes')

plt.show()

# %%
#Confusion matrix
pd.crosstab(test['category'], clf.predict(X_test), rownames=['category'], colnames=['pred category'])
# Out:
# pred category   0   3
# category
# 0              13   0
# 1               4   0
# 2               0   4
# 3               0  25

# %%
View(df4)
# Out:
# <script type="text/Javascript">var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<table border="1" class="dataframe">\  <thead>\    <tr style="text-align: right;">\      <th></th>\      <th>Unnamed: 0</th>\      <th>X1</th>\      <th>advertiser_name</th>\      <th>campaign_group_id</th>\      <th>campaign_id</th>\      <th>device_type</th>\      <th>operating_system</th>\      <th>start_date</th>\      <th>end_date</th>\      <th>impressions</th>\      <th>creative_size_small</th>\      <th>creative_size_medium</th>\      <th>creative_size_large</th>\      <th>impressions_inview</th>\      <th>media_cost</th>\      <th>clicks</th>\      <th>post_click_conv</th>\      <th>post_view_conv</th>\      <th>unique_user_impressions</th>\      <th>unique_user_inview</th>\      <th>unique_user_is_click</th>\      <th>unique_user_post_click_conv</th>\      <th>unique_user_post_view_conv</th>\      <th>ctr</th>\      <th>uniqueperimpression</th>\      <th>cr</th>\      <th>cr.1</th>\      <th>costperimpression</th>\      <th>costperclick</th>\      <th>costperviewconv</th>\      <th>costperclickconv</th>\      <th>temp</th>\      <th>duration</th>\      <th>clicknotconvert</th>\      <th>betterclickconversion</th>\      <th>clicksperdayperimpression</th>\      <th>temp2</th>\      <th>atv</th>\      <th>clickconvperimpression</th>\      <th>campid_cvt</th>\      <th>osid_cvt</th>\      <th>dev_cvt</th>\      <th>ctr/date</th>\      <th>atv/date</th>\      <th>result</th>\      <th>ctr_bin</th>\      <th>unique_user_post_click_conv_bin</th>\      <
# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
df5 = pd.DataFrame()

# %% [markdown]
# <h1> m1 </h1>

# %%
df5['ctr'] = df4['ctr']
df5['creativeL/impression'] = df4['creative_size_large'] / df4['impressions']
df5['creativeS/impression'] = df4['creative_size_small'] / df4['impressions']
df5['creativeM/impression'] = df4['creative_size_medium'] / df4['impressions']
df5['device_type_c'] = pd.Series(df4['device_type'],dtype='category')
df5['os_type_c'] = pd.Series(df4['operating_system'],dtype='category')
df5['impinv/imp'] = df4['impressions_inview'] / df4['impressions']

# %%
#Splitting but not necessary since comparing to OLS ?
df5['train'] = df4['train']
m1_train, m1_test =  df5[df5['train']==True], df5[df5['train']==False]

# %%
m1_X =np.asarray(list(zip(df5['creativeL/impression'],
                          df5['creativeS/impression'],
                          df5['creativeM/impression'],
                          df3['dev_cvt'],
                          df3['osid_cvt'],
                          df5['impinv/imp']
                         )))
m1_Y = np.asarray(df5['ctr'])

# %%
m1 = RandomForestRegressor(n_estimators = 100, min_samples_leaf = 50, n_jobs=-1,
                           random_state=1,oob_score ='TRUE', max_features = 'auto' )

# %%
m1.fit(m1_X,m1_Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=50, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score='TRUE', random_state=1, verbose=0, warm_start=False)

# %%
m1.feature_importances_
# Out:
# array([ 0.05025804,  0.78011444,  0.        ,  0.1028409 ,  0.02913869,
#         0.03764794])

# %%
ctr_hat = m1.predict(m1_X)

# %% [markdown]
# <h1> m2 </h1>

# %%
df5['totalConversionRate'] = (df3['unique_user_post_click_conv'] + 
                              df3['unique_user_post_view_conv']) / df3['impressions']

# %%
m2 = RandomForestRegressor(n_estimators = 100, min_samples_leaf = 50, n_jobs=-1,
                           random_state=1,oob_score ='TRUE', max_features = 'auto')

# %%
View(df5)
# Out:
# <script type="text/Javascript">var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<table border="1" class="dataframe">\  <thead>\    <tr style="text-align: right;">\      <th></th>\      <th>ctr</th>\      <th>creativeL/impression</th>\      <th>creativeS/impression</th>\      <th>creativeM/impression</th>\      <th>device_type_c</th>\      <th>os_type_c</th>\      <th>impinv/imp</th>\      <th>train</th>\      <th>totalConversionRate</th>\    </tr>\  </thead>\  <tbody>\    <tr>\      <th>0</th>\      <td>0.001641</td>\      <td>0.000000</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>other</td>\      <td>iOS</td>\      <td>0.343153</td>\      <td>True</td>\      <td>0.000953</td>\    </tr>\    <tr>\      <th>1</th>\      <td>0.002033</td>\      <td>0.000000</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>other</td>\      <td>iOS</td>\      <td>0.411237</td>\      <td>True</td>\      <td>0.001526</td>\    </tr>\    <tr>\      <th>2</th>\      <td>0.010115</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>desktop</td>\      <td>Windows</td>\      <td>0.686897</td>\      <td>True</td>\      <td>0.006664</td>\    </tr>\    <tr>\      <th>3</th>\      <td>0.002975</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>other</td>\      <td>iOS</td>\      <td>0.793943</td>\      <td>True</td>\      <td>0.000270</td>\    </tr>\    <tr>\      <th>4</th>\      <td>0.002475</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>desktop</td>\      <td>Windows</td>\      <td>0.713236</td>\      <td>True</td>\      <td>0.002116</td>\    </tr>\    <tr>\      <th>5</th>\      <td>0.002089</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>desktop</td>\      <td>MAC OS</td>\      <td>0.821671</td>\      <td>True</td>\      <td>0.000522</td>\    </tr>\    <tr>\      <th>6</th>\      <td>0.002823</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>desktop</td>\      <td>Windows</td>\      <td>0.710840</td>\      <td>True</td>\      <td>0.002368</td>\    </tr>\    <tr>\      <th>7</th>\      <td>0.001744</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>desktop</td>\      <td>Windows</td>\      <td>0.720676</td>\      <td>True</td>\      <td>0.001375</td>\    </tr>\    <tr>\      <th>8</th>\      <td>0.011884</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>desktop</td>\      <td>Windows</td>\      <td>0.640708</td>\      <td>True</td>\      <td>0.007161</td>\    </tr>\    <tr>\      <th>9</th>\      <td>0.005936</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>desktop</td>\      <td>MAC OS</td>\      <td>0.791551</td>\      <td>True</td>\      <td>0.003084</td>\    </tr>\    <tr>\      <th>10</th>\      <td>0.003363</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>desktop</td>\      <td>MAC OS</td>\      <td>0.827915</td>\      <td>True</td>\      <td>0.002242</td>\    </tr>\    <tr>\      <th>11</th>\      <td>0.002437</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>other</td>\      <td>iOS</td>\      <td>0.780331</td>\      <td>True</td>\      <td>0.000174</td>\    </tr>\    <tr>\      <th>12</th>\      <td>0.017528</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>desktop</td>\      <td>other</td>\      <td>0.671587</td>\      <td>True</td>\      <td>0.014760</td>\    </tr>\    <tr>\      <th>13</th>\      <td>0.001934</td>\      <td>1.000000</td>\      <td>0.000000</td>\      <td>0.000000</td>\      <td>desktop</td>\      <td>MAC OS< ...

# %%
m2_Y = np.asarray(df5['totalConversionRate'])
m2_X = np.asarray(list(zip(df5['creativeL/impression'],
                           df5['creativeS/impression'],
                           df5['creativeM/impression'],
                           df3['dev_cvt'],
                           df3['osid_cvt'],
                           df5['impinv/imp'],
                           m1_Y
                                )))

# %%
m2.fit(m2_X,m2_Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=50, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score='TRUE', random_state=1, verbose=0, warm_start=False)

# %% [markdown]
# <h1> m2 result </h1>

# %%
m2.feature_importances_
# Out:
# array([  9.97024918e-02,   2.02332195e-03,   1.06428468e-02,
#          7.50115364e-04,   5.83125877e-04,   6.16137290e-02,
#          8.24684369e-01])

# %%
totalConversionRate_hat = m2.predict(m2_X)

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
# people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')

m2_feature = ('CLi','CSi','Cmi','dev_cvt','osid','impinv/imp','ctr')
y_pos_m2 = np.arange(len(m2_feature))
performance = m2.feature_importances_
ax.barh(y_pos, performance,  align='center')
ax.set_yticks(y_pos_m2)
ax.set_yticklabels(m2_feature)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('importance of attributes m2')

plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(m2_Y,totalConversionRate_hat)
# Out:
# 1.3986923606088435e-06

# %%
#Graph
plt.scatter(df3['impressions'],df5['totalConversionRate'])

# %%
pd.DataFrame(totalConversionRate_hat).describe()
# Out:
#                 0
# count  468.000000
# mean     0.000896
# std      0.000715
# min      0.000204
# 25%      0.000279
# 50%      0.000781
# 75%      0.000945
# max      0.002329

# %%
fig, axes = plt.subplots(figsize=(30,30))
axes.scatter(df3['impressions'],df5['totalConversionRate'],c=['b'])
axes.scatter(df3['impressions'],totalConversionRate_hat,c=['r'])

axes = fig.add_axes()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(30,30))

axes.scatter(df3['impressions'],totalConversionRate_hat,c=['r'])
axes.scatter(df3['impressions'],df5['totalConversionRate'],c=['b'])


axes = fig.add_axes()
plt.show()

# %% [markdown]
# <h1> m3 </h1>

# %%
m3_X = np.asarray(list(zip(df5['creativeL/impression'],
                           df5['creativeS/impression'],
                           df5['creativeM/impression'],
                           df3['dev_cvt'],
                           df3['osid_cvt'],
                           df5['impinv/imp'],
                           ctr_hat
                            )))

# %%
m3 = RandomForestRegressor(n_estimators = 100, min_samples_leaf = 50, n_jobs=-1,
                           random_state=1,oob_score ='TRUE', max_features = 'auto')

# %%
m3.fit(m3_X,m2_Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=50, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score='TRUE', random_state=1, verbose=0, warm_start=False)

# %% [markdown]
# <h1> m3 result </h1>

# %%
m3.feature_importances_
# Out:
# array([  7.44917540e-01,   7.48405813e-02,   4.12444283e-03,
#          2.83113866e-04,   4.65348402e-03,   1.41932407e-01,
#          2.92484311e-02])

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
# people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')

m3_feature = ('CLi','CSi','Cmi','dev_cvt','osid','impinv/imp','ctr_hat')
y_pos_m3 = np.arange(len(m3_feature))
performance = m3.feature_importances_
ax.barh(y_pos, performance,  align='center')
ax.set_yticks(y_pos_m3)
ax.set_yticklabels(m3_feature)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('importance of attributes m3')

m2_feature = ('CLi','CSi','Cmi','dev_cvt','osid','impinv/imp','ctr')
y_pos_m2 = np.arange(len(m2_feature))
performance = m2.feature_importances_
ax.barh(y_pos, performance,  align='center')
ax.set_yticks(y_pos_m2)
ax.set_yticklabels(m2_feature)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('importance of attributes m2=blue and m3=orange')


plt.show()

# %%
m3_hat = m3.predict(m3_X)

# %%
m3_hat
# Out:
# array([ 0.00075113,  0.0007365 ,  0.00162163,  0.00143878,  0.00143878,
#         0.00136057,  0.00143878,  0.00143878,  0.00176355,  0.00136057,
#         0.00136057,  0.00143878,  0.0017426 ,  0.00136057,  0.00136057,
#         0.00143878,  0.00175894,  0.00144382,  0.00136057,  0.00143878,
#         0.00136057,  0.00136057,  0.00174576,  0.00136057,  0.00143878,
#         0.00176258,  0.00143878,  0.00143878,  0.00136057,  0.00145104,
#         0.00136057,  0.00136057,  0.00166837,  0.00145104,  0.00136057,
#         0.00175894,  0.00143878,  0.00143878,  0.00136057,  0.00136057,
#         0.00154342,  0.00174658,  0.00174658,  0.00174658,  0.00035807,
#         0.00035807,  0.00028246,  0.00035807,  0.00035807,  0.00035807,
#         0.00035807,  0.00035807,  0.00035807,  0.00035807,  0.00035807,
#         0.00035807,  0.00028246,  0.00024434,  0.00027434,  0.00035807,
#         0.00075113,  0.00075113,  0.00035807,  0.00024172,  0.00027434,
#         0.00024434,  0.00075113,  0.00024172,  0.00027434,  0.00035807,
#         0.00024434,  0.00143878,  0.00136057,  0.00136057,  0.00143878,
#         0.00176258,  0.00145104,  0.00136057,  0.00018594,  0.00024434,
#         0.00021594,  0.00027434,  0.00018332,  0.00024172,  0.00021594,
